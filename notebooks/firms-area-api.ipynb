# %% [markdown]
# # FIRMS Area API
#
# https://github.com/kamangir/blue-geo/blob/main/blue_geo/.abcli/catalog/firms/README.md

# %%
from bluer_options import string

from bluer_geo.catalog.firms.area import FirmsAreaDatacube
from bluer_geo.host import signature
from bluer_geo.notebooks import show_on_map
from bluer_geo.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🌐  bluer_geo-5.14.1.bluer_flow-5.16.1.bluer_ai-12.136.1.bluer_objects-6.96.1.bluer_options-5.86.1.torch-2.2.2.Python 3.12.9.Darwin 23.6.0..Jupyter-Notebook,
# built on 23 April 2025, 10:26:34

# %% [markdown]
# ---

# %%
datacube = FirmsAreaDatacube()
success, gdf = datacube.ingest()
assert success
# Out:
# 🌐  bluer_geo.catalog.generic.generic.classes.FirmsAreaDatacube.ingest(): metadata @ datacube-firms-area-world-MODIS_NRT-2025-04-18-1
# 🌀  bluer_objects.file.functions: https://firms.modaps.eosdis.nasa.gov/api/area/csv/916ad54ef3787ac6c73802eed8c61735/MODIS_NRT/world/1/2025-04-18 -> /Users/kamangir/storage/abcli/datacube-firms-area-world-MODIS_NRT-2025-04-18-1/firms_area.csv
# 🌐  loaded 5,593 point(s).
# pyogrio._io Created 5,593 records
# 🌀  bluer_objects.metadata.post.post[/Users/kamangir/storage/abcli/datacube-firms-area-world-MODIS_NRT-2025-04-18-1/metadata.yaml]: datacube
# 🌀  bluer_objects.file.save.save_yaml: datacube -> /Users/kamangir/storage/abcli/datacube-firms-area-world-MODIS_NRT-2025-04-18-1/metadata.yaml.

# %%
gdf.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0 -25.14101  -42.95115      305.67  2.23   1.45  2025-04-18         5
# 1 -11.27274  -40.73599      305.21  1.08   1.04  2025-04-18         9
# 2  -9.62250  -37.03759      315.74  1.16   1.07  2025-04-18         9
# 3  -9.61304  -37.03907      325.43  1.16   1.07  2025-04-18         9
# 4  -9.61153  -37.02877      308.94  1.16   1.07  2025-04-18         9
#
#   satellite instrument  confidence version  bright_t31    frp daynight  \
# 0     Terra      MODIS          35  6.1NRT      292.03  15.77        N
# 1     Terra      MODIS          61  6.1NRT      292.00   6.93        N
# 2     Terra      MODIS          91  6.1NRT      296.82  14.22        N
# 3     Terra      MODIS         100  6.1NRT      297.06  26.17        N
# 4     Terra      MODIS          73  6.1NRT      296.59   7.94        N
#
#                       geometry
# 0  POINT (-42.95115 -25.14101)
# 1  POINT (-40.73599 -11.27274)
# 2    POINT (-37.03759 -9.6225)
# 3   POINT (-37.03907 -9.61304)
# 4   POINT (-37.02877 -9.61153)

# %%
show_on_map(gdf.iloc[:1000], zoom_start=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0565f8e29ce59327c38646eabd1fa50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0565f8e29ce59327c38646eabd1fa50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0565f8e29ce59327c38646eabd1fa50 = L.map(
#                 &quot;map_d0565f8e29ce59327c38646eabd1fa50&quot;,
#                 {
#                     center: [16.279052930000002, 65.79692314000002],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_198d4284277290900918f64541f6d2a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_198d4284277290900918f64541f6d2a5.addTo(map_d0565f8e29ce59327c38646eabd1fa50);
#
#
#
#         function geo_json_64f22a31a02dc4a65cc0285e024fc121_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_64f22a31a02dc4a65cc0285e024fc121 = L.geoJson(null, {
#                 onEachFeature: geo_json_64f22a31a02dc4a65cc0285e024fc121_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json